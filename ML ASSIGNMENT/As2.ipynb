# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("temperatures.csv")

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.shape #shape to find out the shape of the dataset
# Out:
# (117, 18)

# %%
df.dtypes # to check the datatypes of the columns
# Out:
# YEAR         int64
# JAN        float64
# FEB        float64
# MAR        float64
# APR        float64
# MAY        float64
# JUN        float64
# JUL        float64
# AUG        float64
# SEP        float64
# OCT        float64
# NOV        float64
# DEC        float64
# ANNUAL     float64
# JAN-FEB    float64
# MAR-MAY    float64
# JUN-SEP    float64
# OCT-DEC    float64
# dtype: object

# %%
print("The missing value in the dataset are:",df.isnull().sum())
# Out:
# The missing value in the dataset are: YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
df.dropna()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.shape
# Out:
# (117, 18)

# %%
df.head(2)
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49

# %%
features = df["YEAR"]
target=df["ANNUAL"]

# %%
features.shape
features=features.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 2
#       1 features.shape
# ----> 2 features=features.values()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
features.reshape(117)

# %%
target
# Out:
# 0      28.96
# 1      29.22
# 2      28.47
# 3      28.49
# 4      28.30
#        ...
# 112    29.81
# 113    29.72
# 114    29.90
# 115    31.63
# 116    31.42
# Name: ANNUAL, Length: 117, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(features,target,test_size=0.2,random_state=45)

# %%
X_train
# Out:
# 2      1903
# 90     1991
# 96     1997
# 110    2011
# 94     1995
#        ...
# 95     1996
# 32     1933
# 3      1904
# 30     1931
# 75     1976
# Name: YEAR, Length: 93, dtype: int64

# %%
y_train
# Out:
# 2      28.47
# 90     29.32
# 96     29.05
# 110    29.82
# 94     30.18
#        ...
# 95     29.58
# 32     28.49
# 3      28.49
# 30     29.15
# 75     29.27
# Name: ANNUAL, Length: 93, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 6
#       2 from sklearn.metrics import mean_squared_error,r2_score
#       4 model = LinearRegression()
# ----> 6 model.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

# %%
y_pred = model.predict(X_test)

mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print(mse)
# Out:
# 0.5321419872724266

# %%
print(r2)
# Out:
# -0.021251010106490664

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))

plt.scatter(y_train,model.predict(X_train),color="blue",label="Training data")
plt.scatter(y_test,y_pred,color="green",label="Testing data")

plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],color="red",linewidth=2,label="Perfect line")
plt.xlabel("Actual Temperature")
plt.ylabel("predicted temperature")
plt.title("Actual vs predicted Temperature for january")
plt.legend()
plt.show()
